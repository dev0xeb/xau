# %% [markdown]
# # 03 - XAUUSD Spread & Liquidity Cost Analysis
#
# Analyzes bid-ask spread percentiles, expansion spikes, and execution cost baselines.

# %%
import pandas as pd

df = pd.read_parquet('../data/processed/features/XAUUSD_M1_features.parquet')
print(df[['estimated_spread_usd', 'estimated_roundtrip_cost_usd', 'estimated_roundtrip_cost_pts']].describe())
