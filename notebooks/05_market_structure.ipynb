# %% [markdown]
# # 05 - XAUUSD Market Structure & Trend Slope Analysis
#
# Analyzes rolling swing highs/lows, trend slope distributions, and consecutive candle momentum.

# %%
import pandas as pd

df = pd.read_parquet('../data/processed/features/XAUUSD_M1_features.parquet')
print(df[['trend_slope_20', 'consecutive_bullish', 'consecutive_bearish']].describe())
