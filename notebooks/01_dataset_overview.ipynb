# %% [markdown]
# # 01 - XAUUSD Dataset Overview & Inspection Notebook
#
# This notebook performs standard exploratory data inspection, loading certified Parquet feature datasets from `data/processed/features/`.

# %%
import pandas as pd
import numpy as np

# Load processed features
df = pd.read_parquet('../data/processed/features/XAUUSD_M1_features.parquet')
print(f"Loaded dataset with {len(df):,} rows and {len(df.columns)} columns.")
df.head()
