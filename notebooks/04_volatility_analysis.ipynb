# %% [markdown]
# # 04 - XAUUSD Volatility & Candle Morphology Analysis
#
# Explores ATR(14), candle body vs wick ratios, and high vs low volatility regime distribution.

# %%
import pandas as pd

df = pd.read_parquet('../data/processed/features/XAUUSD_M1_features.parquet')
print(df[['atr_14', 'vol_rolling_20', 'high_low_range', 'body_size']].describe())
